# %% [markdown]
# pip安装:
# pip install beautifulsoup4
#
# 导入:
# from bs4 import BeautifulSoup

# %% [markdown]
# |转化器            |用例                                  |优点             |缺点           |
# |:---|:---|:---|:---|
# |html.parser      |BeautifulSoup(markup, "html.parser") |<ul><li>python库自带</li><li>中规中矩的速度</li><li>可应用范围广</li></ul> |<ul><li>速度不如lxml</li><li>应用范围不如html5lib</li></ul> |
# |lxml的html转化器   |BeautifulSoup(markup, "lxml")        |<ul><li>速度非常快</li><li>可应用范围广</li></ul>   |<ul><li>外部C语言依赖</li></ul>|
# |lxml的xml转化器    |BeautifulSoup(markup, "xml")         |<ul><li>速度非常快</li><li>当前唯一支持XML的转化器</li></ul>|<ul><li>外部C语言依赖</li></ul>|
# |html5lib          |BeautifulSoup(markup, "html5lib")    |<ul><li>可应用范围非常广</li><li>类似于浏览器转化过程</li><li>创建有效html5页面</li></ul>|<ul><li>非常慢</li><li>外部python依赖</li></ul>|

# %% [markdown]
# BeautifulSoup4对象种类归纳:
# soup = BeautifulSoup('<b class="boldest">Extremely bold</b>')
# 1. bs4.BeautifulSoup
#     特别的Tag
#
# 2. bs4.element.Tag
#     HTML/XML的tag. 如soup.b
#     tag["id"]/tag["class"]获取属性值
#
# 3. bs4.element.NavigableString
#     tag的正文字符. 如soup.b.string
#
# 4. bs4.element.Comment
#     特别的NavigableString. 格式: \<!-- content -->
#
#
# 继承关系:
# bs4.element.PageElement --> bs4.element.Tag --> bs4.BeautifulSoup
# bs4.element.PageElement, str --> bs4.element.NavigableString --> bs4.element.PreformattedString --> bs4.element.Comment

# %% [markdown]
# ```
# 1.bs4.BeautifulSoup
#
# __init__(markup='', features=None, builder=None, parse_only=None, from_encoding=None, exclude_encodings=None, element_classes=None, **kwargs)
#     构造BeautifulSoup对象, HTML或XML的数据结构对象. 参数列表如下:
#         markup - str格式或bytes格式或file-object, 需要转化的内容
#         features - str格式, 指定解析器类型. 列表如下: html.parser/lxml/xml/html5lib. 建议手动指定
#                 builder - TreeBuilder子类, 不依赖于features构建方法
#         parse_only - SoupStrainer对象, 只考虑符合SoupStrainer的文档部分
#         from_encoding - str格式, 当markup为bytes格式内容时, 指定markup的编码类型
# , 用于解码
#         exclude_encodings - list of str格式, 当markup为bytes格式, 排除的编码类型
# 列表
#                 element_classes - dict格式, 映射元素的对象类型, 如Tag/NavigableString等
#         kwargs - 用于与Beautiful Soup 3后向兼容
# ```

# %%
from bs4 import BeautifulSoup

html_doc = """
<p class="story">
Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a>
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>
</p>
<p class="hungry">
<a href="http://www.baidu.com">catch</a>
<a href="http://www.google.com">try</a>
</p>
"""
soup = BeautifulSoup(html_doc)
list = soup.a.
print(list)
# Out:
# <p class="hungry">
# <a href="http://www.baidu.com">catch</a>
# <a href="http://www.google.com">try</a>
# </p>

# %% [markdown]
# ```
# 2.bs4.element.Tag
#
# children
#     tag的子节点generator
#     item可以为NavigableString或子Tag
#
# contents
#     tag的子节点列表
#     item可以为NavigableString或子Tag
#
# descendants
#     递归查找tag的子孙节点
#
# string
#     当tag只包含一个子节点, 并且该子节点为NavigableString时, 获取该NavigableString
#
# stripped_strings
#     tag的子孙NavigableString节点generator
#     删除多余空格
#
# parent
#     tag的父节点
#
# parents
#     递归查找tag的祖辈节点
#
# previous_sibling
#     上一个兄弟节点(含相同父节点)
#
# next_sibling
#     下一个兄弟节点(含相同父节点)
#
# previous_siblings
#     位于之前的所有兄弟节点
#
# next_siblings
#     位于之后的所有兄弟节点
#
# previous_element
#     上一个节点元素
#
# next_element
#     下一个节点元素
#
# previous_elements
#     之前所有节点元素
#
# next_elements
#     之后所有节点元素
#
# find_all(name, attrs, recursive, string, limit)
#     从tag的子孙节点中查找所有符合条件的内容. 参数列表如下:
#         name - str/re格式, 子孙节点的tag名称
#         attrs - dict格式, tag的属性键值对
#         recursive - bool格式, 是否递归查找间接子类节点. 默认为True
#         string - str格式, 查找NavigableString匹配的内容. BeautifulSoup 4.4.0新增参数, 之前版本为text参数
#         limit - int格式, 获取到指定数量结果后, 停止查找
#         ** 所有str都可以使用RE格式
#
# find(name, attrs, recursive, string)
#     从tag的子孙节点中查找第一个符合条件的内容. 参数列表如下:
#         name - str/re格式, 子孙节点的tag名称
#         attrs - dict格式, tag的属性键值对
#         recursive - bool格式, 是否递归查找间接子类节点. 默认为True
#         string - str格式, 查找NavigableString匹配的内容. BeautifulSoup 4.4.0新增参数, 之前版本为text参数
#         ** 所有str都可以使用RE格式
#
# find_parents(name, attrs, string, limit)
#     从tag的祖辈节点中查找所有符合条件的内容. 参数列表如下:
#         name - str/re格式, 祖辈节点的tag名称
#         attrs - dict格式, tag的属性键值对
#         string - str格式, 查找NavigableString匹配的内容. BeautifulSoup 4.4.0新增参数, 之前版本为text参数
#         limit - int格式, 获取到指定数量结果后, 停止查找
#
# find_parent(name, attrs, string)
#     从tag的祖辈节点中查找第一个符合条件的内容. 参数列表如下:
#         name - str/re格式, 祖辈节点的tag名称
#         attrs - dict格式, tag的属性键值对
#         string - str格式, 查找NavigableString匹配的内容. BeautifulSoup 4.4.0新增参数, 之前版本为text参数
#
# find_previous_siblings(name, attrs, string, limit)
#     从tag的之前兄弟节点中查找所有符合条件的内容. 参数列表如下:
#         name - str/re格式, 兄弟节点的tag名称
#         attrs - dict格式, tag的属性键值对
#         string - str格式, 查找NavigableString匹配的内容. BeautifulSoup 4.4.0新增参数, 之前版本为text参数
#         limit - int格式, 获取到指定数量结果后, 停止查找
#
# find_previous_sibling(name, attrs, string)
#     从tag的之前兄弟节点中查找所有符合条件的内容. 参数列表如下:
#         name - str/re格式, 兄弟节点的tag名称
#         attrs - dict格式, tag的属性键值对
#         string - str格式, 查找NavigableString匹配的内容. BeautifulSoup 4.4.0新增参数, 之前版本为text参数
#
# find_next_siblings(name, attrs, string, limit)
#     从tag的后续兄弟节点中查找所有符合条件的内容. 参数列表如下:
#         name - str/re格式, 兄弟节点的tag名称
#         attrs - dict格式, tag的属性键值对
#         string - str格式, 查找NavigableString匹配的内容. BeautifulSoup 4.4.0新增参数, 之前版本为text参数
#         limit - int格式, 获取到指定数量结果后, 停止查找
#
# find_next_sibling(name, attrs, string)
#     从tag的后续兄弟节点中查找所有符合条件的内容. 参数列表如下:
#         name - str/re格式, 兄弟节点的tag名称
#         attrs - dict格式, tag的属性键值对
#         string - str格式, 查找NavigableString匹配的内容. BeautifulSoup 4.4.0新增参数, 之前版本为text参数
# ```

# %% [markdown]
# ```
# 3.bs4.element.NavigableString
#
# parent
#     NavigableString的父节点
# ```

# %%
import requests
from bs4 import BeautifulSoup

header = {"User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36"}
proxy = {'http': 'socks5://127.0.0.1:1080', 'https': 'socks5://127.0.0.1:1080'}
# 评论页面: F12  -->  network  -->  productPageComments.action  -->  general:request url
response = requests.request('GET', 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=100012043978&score=0&sortType=5&page=0&pageSize=10&isShadowSku=0&fold=1', headers=header, proxies=proxy)
soup = BeautifulSoup(response.text)
#comment = soup.find("div", attrs={"class": "comment-item"})
#user_name = comment.find("div", attrs={"class": "user-info"}).string
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    fetchJSON_comment98({"jwotestProduct":null,"score":0,"comments":[{"id":15131310633,"guid":"f6d68ae22b0d2b121df1cee3a4bb6c46","content":"终于到手一瓶，年夜饭有着落了，国酒茅台，名不虚传，包装完美，无漏酒，带酒杯，赤水河畔固态纯粮酿造，纯正坤沙工艺，酱香突出，空杯留香，酒花持久，酒质微黄无杂质，京东快递极速，第二天到货，有专门的溯源码，防伪做到极致！","creationTime":"2021-01-03 21:38:35","isDelete":false,"isTop":false,"userImageUrl":"misc.360buyimg.com/user/myjd-2015/css/i/peisong.jpg","topped":0,"replies":[],"replyCount":0,"score":5,"imageStatus":1,"usefulVoteCount":11946,"userClient":4,"discussionId":847037757,"imageCount":8,"anonymousFlag":0,"plusAvailable":201,"mobileVersion":"","images":[{"id":1329240496,"imgUrl":"//img30.360buyimg.com/n0/s128x96_jfs/t1