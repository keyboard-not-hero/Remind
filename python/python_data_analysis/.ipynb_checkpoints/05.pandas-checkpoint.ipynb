# %% [raw]
# pandas -- 用于处理包含列名的表格型和混杂型数据
#
# 安装
# pip install pandas
#
# 导入
# import pandas as pd
#
# 继承体系:
#     Index --> Int64Index --> RangeIndex

# %%
# 例1.测试Series是否包含指定索引值
import pandas as pd

obj2 = pd.Series([4, 7, -5, 3], index=['d', 'b', 'a', 'c'])
print('b' in obj2)
# Out:
# True

# %%
# 例2. Series values的花式索引和元素级运算
import pandas as pd

obj2 = pd.Series([4, 7, -5, 3], index=['d', 'b', 'a', 'c'])
print(obj2[obj2 > 0])
print(obj2 * 2)
# Out:
# d    4
# b    7
# c    3
# dtype: int64
# d     8
# b    14
# a   -10
# c     6
# dtype: int64

# %%
# 例3. DataFrame
import pandas as pd

# dict的key作为DataFrame的列明. DataFrame的每一列都是Series
data = {
        'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
        'year': [2000, 2001, 2002, 2001, 2002, 2003],
        'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]
}
df = pd.DataFrame(data)
print(df)
# 取列与行内容, df['year']也可以表示为df.year
print(df['year']) 
print(df.loc[3])
# 取头几行内容
print(df.head())
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: year, dtype: int64
# state    Nevada
# year       2001
# pop         2.4
# Name: 3, dtype: object
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
# 例4.DataFrame与Series进行计算
import numpy as np
import pandas as pd

frame = pd.DataFrame(np.arange(12.).reshape((4, 3)), columns=list('bde'), index=['Utah', 'Ohio', 'Texas', 'Oregon'])
series = frame.iloc[0]
print(frame.sub(series, axis='columns'))
series2 = frame['b']
print(frame.sub(series2, axis='index'))
# Out:
#           b    d    e
# Utah    0.0  0.0  0.0
# Ohio    3.0  3.0  3.0
# Texas   6.0  6.0  6.0
# Oregon  9.0  9.0  9.0
#           b    d    e
# Utah    0.0  1.0  2.0
# Ohio    0.0  1.0  2.0
# Texas   0.0  1.0  2.0
# Oregon  0.0  1.0  2.0

# %%
# 例5.DataFrame数据处理
import pandas as pd

# 第一步: 数据加载

# 第二步: 数据清洗(特殊值, 缺失数据, 重复行)
# 特殊值处理: replace
# 缺失数据: fillna
# 重复行丢弃: drop_duplicates

# 第三步: 数据规整(合并, 重塑)
# 合并: 
#    join - 根据行索引进行列合并
#    merge - 根据列作为key进行列合并
#    concat - 沿行或列进行堆叠
# 重塑: 
#     stack - 将列索引转化为行索引. 默认操作多层索引最里层
#     unstack - 将行索引转化为列索引. 默认操作多层索引最里层
#     set_index - 使用列作为行索引
#     reset_index - 将行索引转化为列
#     swaplevel - 在指定轴上交换多层索引的两个层级
#     combine_first - 使用一个DataFrame上的值, 填充另一个DataFrame同位置的NaN值
#     pivot - 将列分配为index/columns/values, 改造形状

# 第四步: 数据分组
#    groupby - 获取分组对象

# %% [raw]
# pandas模块
# method:
# concat(objs, axis=0, join='outer', ignore_index=False, keys=None, levels=None, names=None, verify_integrity=False, sort=False, copy=True)
#     沿着行或列进行堆叠. 参数列表如下:
#         objs - sequence of Series/DataFrame或dict of Series/DataFrame格式, 进行堆叠的Series或DataFrame. dict的key作为keys参数
#         axis - int或str格式, 0和'index'代表沿着行方向进行上下堆叠; 1和'columns'代表沿着列方向进行左右堆叠
#         join - str格式, 指定与合并方式相对的, 另一个轴内容的合并方式. 列表如下:
#             'inner' - 只保留该轴上都包含内容的行或列
#             'outer' - 保留所有列或行
#         ignore_index - bool格式, 是否忽略堆叠方向的原索引内容. 从新规划为0, 1, ..., n-1
#         keys - sequence格式, 每objs中的每个堆叠Series/DataFrame在堆叠方向上, 最外层新增一层索引. 此时ignore_index参数不能为True
#         names - list格式, 指定堆叠方向上的多层索引name
#         verify_integrity - bool格式, 是否验证堆叠方向上有重复内容(索引或内容)
#         sort - bool格式, 当join为'outer'时, 在非堆叠轴上排序
#
# cut(x, bins, right=True, labels=None, retbins=False, precision=3, include_lowest=False, duplicates='raise', ordered=True)
#     将值划分到离散区间. 参数列表如下:
#         x - sequence格式, 需要区间划分的一维数组
#         bins - int或sequence of scalars或IntervalIndex对象格式, 划分类型. 列表如下:
#             int - 取x中的最大值和最小值, 在该范围区间内等间隔划分为n份
#             sequecne of scalars - 指定一系列划分的边界值
#         right - bool, 在每个区间中, 是否包含右边界. 为True时, (min, max]区间; 为False时, [min, max)区间. 不适用于bins为IntervalIndex
#         labels - sequence格式, 每个区间的显示标签, 长度必须与划分区间数一致
#         retbins - bool格式, 是否返回分块
#         pecision - int格式, 分区边界保留的有效位数(小数位数)
#         include_lowest - bool格式, 第一个区间是否必须包含起始数字
#         duplicates - str格式, 当遇到同时指定重复边界值时, 所采用的处理方式. 列表: 'raise'/'drop'
#
# get_dummies(data, prefix=None, prefix_sep='_', dummy_na=False, columns=None, sparse=False, drop_first=False, dtype=None)
#     将分类变量转化为哑变量(指标变量).
#     哑变量: 某一列中含有k个不同的值，则可以派生出一个k列(其值全为1和0)
#     参数列表如下:
#         data - sequence或Series或DataFrame格式, 列表如下:
#             sequence - 将序列作为派生哑变量的列
#             Series - 类似于sequence
#             DataFrame - 将指定的列转化为哑变量. 默认只转化dtype为object和category格式的列
#         prefix - str或list of str或dict of str格式, 添加到转化后列名的前缀. 列表如下:
#             str - 统一添加到所有转化哑变量列前缀
#             list of str - 分别指定添加到多个哑变量组的前缀, 长度需要与转化的哑变量组数相同
#             dict of str - 指定列名与转化后要添加的哑变量组前缀pair, dict长度需要与转化的哑变量组数相同
#         prefix_sep - str格式, 指定添加前缀和哑变量的分隔符
#         dummy_na - bool格式, 是否给每组转化后哑变量组添加一列代表NaN的内容
#         columns - sequence格式, 指定需要转化为哑变量组的列. 默认为所有格式为object和category的列
#         sparse - bool格式, 转化后的内容是被稀疏矩阵数组支持, 还是被标准numpy数组支持
#         drop_first - bool格式, 是否获取k-1哑变量组, 除去第一个变量类型列
#         dtype - dtype格式, 指定哑变量列元素类型. 默认为uint8
#
# isnull(obj)
#     检测数组中的NaN值. 参数如下:
#         obj - array_like格式, 检测元素是否为NaN值
#
# notnull(obj)
#     检测数组中的非NaN值. 参数如下:
#         obj - array_like格式, 检测元素是否为非NaN值
#
# qcut(x, q, labels=None, retbins=False, precision=3, duplicates='raise')
#     将值按分位点划分到离散区间. 参数列表如下:
#         x - sequence格式, 需要区间划分的一维数组
#         q - int或sequence of float格式, 划分类型. 列表如下:
#             int - 取x中的最大值和最小值, 在该范围区间内划分为n份, 每份包含的item尽量相同
#             sequecne of float - 指定一系列划分的边界分位点
#         labels - sequence格式, 每个区间的显示标签, 长度必须与划分区间数一致
#         retbins - bool格式, 是否返回分块
#         pecision - int格式, 分区边界保留的有效位数(小数位数)
#         include_lowest - bool格式, 第一个区间是否必须包含起始数字
#         duplicates - str格式, 当遇到同时指定重复边界值时, 所采用的处理方式. 列表: 'raise'/'drop'
#
# read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, skip_blank_lines=True, chunksize=None)
#     从csv格式文件中读取内容. 参数列表如下:
#         filepath_or_buffer - str或file-like格式, 读取的文件
#         sep - str格式, 列之间的分隔符, 当大于一个字符时, 自动使用regular expression进行解释
#         delimiter - str格式, 与sep类似
#         header - int或list of int格式, 作为列名称的行号
#         names - array_like格式, 指定列名. header必须为None
#         index_col - int/str或list of int/str或False格式, 作为行索引的列
#         usecols - sequence或callable格式, sequence代表只提取指定列内容, 可使用label或position; callable代表与列数量同等长度, 取对应True的列
#         squeeze - bool格式, 当只有一列内容时, 是否返回Series
#         prefix - str格式, 当没有header时, 使用<prefix><N>格式添加列名
#         mangle_dupe_cols - bool格式, 将列名相同的列名重命名为<col_name>, <col_name>.1, ..., <col_name>.N .当前只能为True
#         dtype - dtype或dict格式, 指定元素类型. dict可分别对不同列指定dtype
#         engine - str格式, 选择使用的读取转化引擎. 列表: 'c'/'python'
#         converters - dict格式, 对不同列做处理. key可以为label或position
#         true_values - list格式, bool列视为True的内容
#         false_values - list格式, bool列视为False的内容
#         skipinitialspace - bool格式, 忽略分隔符后的空格
#         skiprows - sequence或int或callable格式, 指定需要跳过的行. 索引从0开始. callable返回列表中, True对应的内容被跳过
#         skipfooter - int格式, 指定文件的最后几行不读取. 不支持engine='c'
#         nrows - int格式, 只读取文件的指定行数(header不包含在计数内)
#         na_values - str或sequence或dict格式, 指定文件内视为缺失值的字符串. dict可用于分别指定不同列包含不同缺失值指示
#         keep_default_na - bool格式, 是否保留原来的已有NaN. 情况如下:
#             keep_default_na为True, na_values指定, na_values添加到原有NaN之后
#             keep_default_na为True, na_values未指定, 只有原有NaN解释
#             keep_default_na为False, na_values指定, 只有na_values指定有效
#             keep_default_na为False, na_values未指定, 没有内容解释为NaN
#         na_filter - bool格式, 是否指定使用NaN解释. 大文件没有missing值时, 关闭可提升性能
#         skip_blank_lines - bool格式, 是否跳过空白行. 为False时, 改行所有列解释为NaN
#         chunksize - int格式, 文件按指定块大小逐块读取. 避免读取大文件时内存过载. 此时返回TextFileReader对象, 可使用for循环读取
#
# set_option(key, value)
#     配置pandas工具参数. 参数列表如下:
#         key - str格式, 参数key, 列表如下:
#             display.max_rows - 最多显示的行数
#             display.max_columns - 最多显示的列数
#             display.width - 允许单行显示的字符宽度. 默认为75
#         value - object格式, 根据key参数设置对应参数的值
#     ** 更多参数参考帮助文档
#
#
# class:
# DataFrame
# attribute:
# columns --> Index
#     获取列名
#
# dtypes
#     获取各列的元素类型
#
# iloc[<spec>]
#     获取指定行内容. <spec>格式:
#         <row_num>[, <col_num>]
#         <row_num>/<col_num>列表如下:
#             int - 行/列所在行列数
#             list of ints - 行/列所在行列数
#             int切片 - 获取切片范围内容
#             array of bool - 与行/列长度相同的布尔值序列, 取True对应索引处的内容
#             callable - 使用表达式, array of bool进阶. 格式: df.loc[<expression>]
#
# index --> Index
#     获取行索引
#
# loc[<spec>]
#     获取指定行内容. <spec>格式:
#         <row_label>[, <col_label>]
#         <row_label>/<col_label>列表如下:
#             label - 行/列标签
#             list of labels - 行/列标签列表
#             label切片 - 适用于行/列标签为整数或单字符. 如: df.loc[['a':'f']]
#             array of bool - 与行/列长度相同的布尔值序列, 取True对应索引处的内容
#             Series - 类似于array of bool, Series值为bool格式, index用于指定标签对齐(打乱顺序)
#             callable - 使用表达式, array of bool进阶. 格式: df.loc[<expression>]
#
# method:
# __init__(data=None, index=None, columns=None, dtype=None, copy=False)
#     构造DataFrame. 参数列表如下:
#         data - ndarray或Iterable或dict或DataFrame格式, DataFrame来源数据, dict的key作为DataFrame的列名
#         index - Index对象或array_like格式, 作为行索引的内容, 缺失索引行值为NaN. 默认为RangeIndex(0, 1, 2, ..., n)
#         columns - Index对象或array_like格式, 作为列名称的内容, 缺失列值为NaN. 默认为RangeIndex(0, 1, 2, ..., n)
#         dtype - data-type格式, 元素数据类型
#         copy - bool格式, 是否为原数据拷贝. 只作用于data为2d-ndarray和DataFrame
#
# combine_first(other)
#     使用一个DataFrame上的值, 填充另一个DataFrame同位置的NaN值. 参数列表如下:
#         other - DataFrame格式, 用于填充内容. 两个DataFrame大小可以不一致, 结果dimension为(max_row, max_col)
#
# describe(percentiles=None, include=None, exclude=None, datetime_is_numeric=False) --> DataFrame/Series
#     描述性统计信息. 参数列表如下:
#         percentiles - list_like格式, 返回指定百分比处的数字. 默认为[0.25, 0.5, 0.75], 中位数总是包含其中
#         include - 'all'或sequence of dtype格式, 允许生成统计信息的类型列. 默认所有数字列生成统计信息. 参数解释如下:
#             'all' - 所有类型dtype列都生成统计信息
#             sequence of dtype - 指定dtype类型的列生成统计信息. 格式列表:
#                 np.number - 数字类型
#                 np.int8/16/32/64 - 指定位数整数
#                 np.float32/64 - 指定位数浮点数
#                 np.complex64/128 - 指定位数复数
#                 np.bool - 布尔值
#                 np.object - 包含str在内的其他对象
#         exclude - sequence of dtype格式, 不允许生成统计信息的类型列. 参数可参考include
#         datetime_is_numeric - bool格式, 是否将np.datetime64对象视为数字
#
# drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise')
#     丢弃指定行或列. 参数列表如下:
#         labels - label或sequence格式, 使用行/列的label名称而非索引
#         axis - int或str格式, int中, 0代表行索引, 1代表列索引; str中, 'index'代表行索引, 'columns'代表列索引
#         index - label或sequence格式, 使用行的label名称
#         columns - label或sequence格式, 使用列的label名称
#         level - int或level_name, 指定多层索引中的层级
#         inplace - bool格式, 拷贝或inplace操作
#         errors - str格式, 处理异常的方式. 列表: ignore/raise
#
# dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
#     移除missing值. 参数列表如下:
#         axis - int或str格式, 0或'index'代表移除行; 1或'columns'代表移除列
#         how - str格式, 移除missing值的方式. 列表如下:
#             'any' - 该行/列包含一个或以上NA就进行移除
#             'all' - 该行列必须所有内容为NA才进行移除
#         thresh - int格式, 行/列必须有指定个非NaN值才保留. 优先级高于how
#         subset - sequence格式, 从另一个轴的指定行/列进行how或thresh资格判定
#         inplace - bool格式, 是否为拷贝或inplace. inplace时返回None
#
# drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
#     丢弃重复行. 参数列表如下:
#         subset - col_label或seqence of col_label格式, 只考虑指定列, 并检测其联合内容是否重复
#         keep - str或bool格式, 重复行标记类型. 参数列表如下:
#             'first' - 除第一个出现, 其他重复出现的标记为重复行
#             'last' - 除最后一个出现, 其他出现的标记为重复行
#             False - 所有重复的都标记为重复行
#         inplace - bool格式, 结果为拷贝或inplace
#         ignore_index - bool格式, 是否忽略原来的行索引, 修改为0, 1, 2, ..., n-1
#
# duplicated(subset=None, keep='first')
#     检测所有行是否为重复内容行. 参数列表如下:
#         subset - col_label或seqence of col_label格式, 只考虑指定列, 并检测其联合内容是否重复
#         keep - str或bool格式, 重复行标记类型. 参数列表如下:
#             'first' - 除第一个出现, 其他重复出现的标记为重复行
#             'last' - 除最后一个出现, 其他出现的标记为重复行
#             False - 所有重复的都标记为重复行
#
# fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None)
#     替换填充missing值. 参数列表如下:
#         value - scalar或dict或Series或DataFrame格式, 用于填充的值. 列表如下:
#             scalar - int/float/str等类型, 用于填充所有包含NaN的单元
#             dict - 指定各列的填充值
#             Series - 指定各列的填充值
#             DataFrame - 指定单元(行列交接)的填充值
#         method - str格式, 填充方式. 列表如下:
#             'backfill'/'bfill' - 在行/列上进行后向填充
#             'pad'/'ffill' - 在行/列上进行前向填充
#         axis - int或str格式, 用于操作的轴. 0或'index'代表在行索引上操作; 1或'columns'代表在列索引上操作
#         inplace - bool格式, 指定操作为拷贝或inplace. inplace操作返回None
#         limit - int格式, 当指定method时, 代表前/后向连续填充的数量; 当未指定method时, 代表指定轴上允许填充的个数
#
# groupby(by=None, axis=0, level=None, as_index=True, sort=True, group_keys=True, observed=False, dropna=True)
#     根据指定列进行分组. 参数列表如下:
#         by - dict/Series或function或str或list of str格式, 分组依据. 列表如下:
#             dict - key作为行索引对齐, value作为分组依据. 可指定新value作为分组规则
#             Series - 行索引对齐, value作为分组依据
#             function - 对返回结果进行分类
#             str - 根据指定列label分组
#             list of str - 根据多个指定labels分组
#         axis - int或str格式, 沿着指定轴进行分隔. 0和'index'代表沿着上下方向; 1和'columns'代表沿着左右方向
#         level - int或str或sequence格式, 根据行索引进行分组
#         as_index - bool格式, 是否将分类的列作为结果的行索引
#         sort - bool格式, 是否将分组结果进行排序. 关闭以提升性能
#         dropna - bool格式, 是否丢弃NaN的分类
#
# info(verbose=None, buf=None, max_cols=None, memory_usage=None, show_counts=None)
#     DataFrame的简略汇总信息. 参数列表如下:
#         verbose - bool格式, 是否显示列的metadata信息
#         buf - writable buffer格式, 用于输出内容. 默认为sys.stdout
#         max_cols - int格式, info信息最大支持列数
#         memory_usage - bool或str格式, 是否显示内存用例, str格式可指定显示用例格式
#         show_counts - bool格式, 是否显示Not-Null计数
#
# join(other, on=None, how='left', lsuffix='', rsuffix='', sort=False)
#     根据行索引合并其他DataFrame的列. 参数列表如下:
#         other - DataFrame或Series或list of DataFrame格式, 需要添加到当前的列内容
#         on - str或sequence格式, 指定调用者的指定列与other的行索引对齐. squence适用于other为多层索引的情况. 默认使用行索引对齐
#         how - str格式, 指定的join类型. 列表如下:
#             left - 调用者全部行和other部分行(两者交集)
#             right - 调用者部分行与other全部行
#             outer - 调用者和other的全部行
#             inner - 调用者和other的交集行
#         lsuffix - str格式, 当调用者与other的列名重复时, 添加到调用者的后缀
#         rsuffix - str格式, 当调用者与other的列名重复时, 添加到other的后缀
#         sort - bool格式, 结果是否根据join key进行排序
#
# melt(id_vars=None, value_vars=None, var_name=None, value_name='value', col_level=None, ignore_index=True)
#     将列索引转化为列. 参数列表如下:
#         id_vars - tuple或list或ndarray格式, 用于作为标识的列
#         value_vars - tuple或list或ndarray格式, 转化为列的列索引, 如果未指定, 则所有未使用id_vars标注的列
#         var_name - scalar格式, 用于value_vars合并后的列名. 默认为'variable'
#         value_name - scalar格式, 用于values的列名
#         col_level - int或str格式, 当为多层列索引时, 指定需要转化的层级
#         ignore_index - bool格式, 是否忽略原行索引, 进行另外自动配置为0, 1, ..., n-1
#
# merge(right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False,
#     suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
#     根据关键列合并其他DataFrame的列. 参数列表如下:
#         right - DataFrame或Series格式, 合并的对象
#         how - str格式, 合并类型. 列表如下:
#             left - 调用者全部行和other部分行(两者交集)
#             right - 调用者部分行与other全部行
#             outer - 调用者和other的全部行
#             inner - 调用者和other的交集行
#             cross - 在调用者的每一个item上, 将other的item遍历一次. 结果为length(self) * length(other)
#         on - lable或list格式, 指定合并参考的列或多层索引的层级名称. list可指定多列
#         left_on - lable或list格式, 指定调用者的合并参考的列或多层索引的层级名称. 用于两个对象的合并列名称不同时
#         right_on - lable或list格式, 指定other的合并参考的列或多层索引的层级名称. 用于两个对象的合并列名称不同时
#         left_index - bool格式, 指定合并是否根据调用者行索引作为关键key
#         right_index - bool格式, 指定合并是否根据other行索引作为关键key
#         sort - bool格式, 结果是否根据合并列进行排序
#         suffixes - sequence格式, 指定合并后重复列的不同后缀
#         copy - bool格式, 结果是否为拷贝. 为False时, 尽量避免为拷贝
#         indicator - bool格式, 是否在合并后新增一列, 代表每行内容在合并前的情况. 情况列表: left_only/right_only/both
#         validate - str格式, 验证合并列内容是否具有唯一性. 可选列表如下:
#             one_to_one - 两个DataFrame合并列是否都唯一, 即"1:1"
#             one_to_many - 左边DataFrame合并列是否唯一, 即"1:m"
#             one_to_many - 右边DataFrame合并列是否唯一, 即"m:1"
#             many_to_many - 不检查唯一性, 即"m:m"
#
# pivot(index=None, columns=None, values=None)
#     将列分配为index/columns/values, 改造形状. 参数列表如下:
#         index - str或object或list of str, 指定作为行索引的列. list代表指定多个列作为多层行索引, list[0]为level0, 类推...
#         columns - str或object或list of str, 指定作为列索引的列, list代表指定多个列作为多层列索引
#         values - str或object或list of str, 指定作为值的列. 默认所有余下的列都作为值. 多个值列作为列索引第1层(position 0)
#
# reindex(labels=None, index=None, columns=None, axis=None, method=None, copy=True, level=None, fill_value=nan, limit=None, tolerance=None)
#     重新设置行列索引. 参数列表如下:
#         labels - array_like格式, 指定重新配置的行列索引. 原数据不存在该行列label时, 填充fill_value指定的值
#         index - array_like格式, 指定重新配置的行索引. 原数据不存在该行label时, 填充fill_value指定的值
#         columns - array_like格式, 指定重新配置的列索引. 原数据不存在该列label时, 填充fill_value指定的值
#         axis - int或str格式, int中, 0代表行索引, 1代表列索引; str中, 'index'代表行索引, 'columns'代表列索引
#         method - str格式, 缺失数据的填充方式, 操作对象索引必须已排序, 即经过sort_index处理. 列表如下:
#             'backfill'/'bfill' - 后向填充一行/列
#             'pad'/'ffill' - 前向填充一行/列
#             'nearest' - 索引必须为整数, 缺失行/列填充为最近的数字索引值
#         copy - bool格式, 原数组的拷贝或inplace. 只有当新索引与原来的索引完全一致, 并且该参数为False时, 才能实现inplace
#         level - int或level_name, 指定在多层级索引中, 操作的层级
#         fill_value - int/str/bool等任意格式, 填充的用于替代missing的值. 默认为NaN
#         limit - int格式, method对应允许连续填充的个数. 使用该参数时, 参数指定的索引必须已排序
#
# replace(to_replace=None, value=None, inplace=False, limit=None, regex=False, method='pad')
#     替换DataFrame中的值. 参数列表如下:
#         to_replace - int/float/str/regex/list/dict/Series格式, 将要被替换的值. 参数列表如下:
#             int/float/str/regex - 指定某个将要被替换的值
#             list - item为int/float/str/regex, 指定一系列要被替换的值
#             dict - 指定替换映射, key为被替换内容, val为替换后内容. 此时value参数必须为None
#             Series - 指定替换映射, index为被替换内容, val为替换后内容. 此时value参数必须为None
#         value - int/float/str/regex/list/dict格式, 替换后的内容. 参数列表如下:
#             int/float/str/regex - 指定替换后的值
#             list - item为int/float/str/regex, 指定一系列替换后的值. 并且与to_replace参数的list长度一致
#         inplace - bool格式, 结果为拷贝或者inplace
#         limit - int格式, method参数拓展选项, 前/后向连续填充限制
#         regex - bool格式, to_replace和value是否使用regular expression
#         method - str格式, 用于to_replace参数为scalar和list时, to_place内容被前/后向填充. 列表: 'pad'/'ffill'/'bfill'/'backfill'
#
# reset_index(level=None, drop=False, inplace=False, col_level=0, col_fill='')
#     将行索引转化为列. 参数如下:
#         level - int或str或sequence格式, 指定需要转化为列的行索引. 默认为全部行索引转化为列
#         drop - bool格式, 是否丢弃行索引, 而不是转化为列, 并且重新生成默认行索引
#         inplace - bool格式, 结果为拷贝或inplace
#         col_level - int或str格式, 当列索引为多层级索引时, 行索引转化的列名放置到哪个层级. 默认为第一层级
#         col_fill - object格式, 当行索引被转化为列时, 当前列的其他层索引名称填充内容
#
# set_index(keys, drop=True, append=False, inplace=False, verify_integrity=False)
#     使用列作为行索引. 参数列表如下:
#         keys - label或sequence of lables格式, 指定作为行索引使用的单个列或多个列
#         drop - bool格式, 是否删除作为行索引的列
#         append - bool格式, 是否将转化为行索引的列, 作为多层索引的内层索引添加到原行索引后. 默认删除原行索引
#         inplace - bool格式, 结果作为拷贝或者inplace
#         verify_integrity - bool格式, 是否检测结果的行索引是否重复. 关闭检测能提升性能
#
# sort_index(axis=0, level=None, ascending=True, inplace=False, kind='quicksort', na_position='last', sort_remaining=True, ignore_index=False, key=None)
#     根据不同轴索引进行排序. 参数列表如下:
#         axis - int或str格式, int中, 0代表行索引, 1代表列索引; str中, 'index'代表行索引, 'columns'代表列索引
#         level - int/level_name/list of ints/list of level_name格式, 在多层索引中, 指定排序依据的索引层级
#         ascending - bool格式或sequence of bools, 指定各层级的排序规则
#         inplace - bool格式, 指定结果为拷贝或inplace结果
#         kind - str格式, 排序使用的算法. 可选列表: 'quicksort'/'mergesort'/'heapsort'
#         na_position - str格式, 指定NaN放置在起始或结束位置. 可选列表: 'first'/'last'
#         sort_remaining - bool格式, 当为True并且排序轴为多层索引时, 除排序指定层级外, 其他层级也依次排序
#         ignore_index - bool格式, 是否忽略排序之前的label, 使用0, 1, ..., n-1替换
#         key - callable格式, 将索引进行处理后再进行排序
#
# stack(level=-1, dropna=True)
#     将列索引转化为行索引. 参数列表如下:
#         level - int或str或list格式, 指定转化的列索引层级(level position/name), list代表转化多层
#         dropna - bool格式, 是否丢弃行内容全部为NaN的行
#
# swaplevel(i=-2, j=-1, axis=0)
#     在指定轴上交换多层索引的两个层级. 参数列表如下:
#         i/j - int或str格式, 指定层级position或name, 用于交换层级
#         axis - int或str格式, 0或'index'代表上下方向轴; 1或'columns'代表左右方向轴
#
# unstack(level=-1, fill_value=None)
#     将行索引转化为列索引. 参数列表如下:
#         level - int或str或list格式, 指定转化的行索引层级(level position/name), list代表转化多层
#         fill_value - int或str格式, 使用指定内容替换NaN
#
#
# Series
# attribute:
# dtype
#     获取值的dtype
#
# index
#     Series索引内容
#
# values
#     Series正文内容
#
# method:
# __init__(data=None, index=None, dtype=None, name=None, copy=False, fastpath=False)
#     构造Series. 参数列表如下:
#         data - array_like或Iterable或dict格式, 提供给Series的内容
#         index - array_like或Index对象格式, Series的索引内容, 当data为dict时, index未提供而dict提供的索引无效, index有而dict不包含的索引值为NaN
#         dtype - data-type格式, Series内容的类型
#         name - str格式, Series的名称
#         copy - bool格式, Series为拷贝或者视图
#
# map(arg, na_action=None)
#     元素级值替换. 参数列表如下:
#         arg - function或dict或Series对象格式, 指定替换映射. Series不包含在arg映射中的key, 默认全部为NaN. 可使用dict子类实现__missing__方法(defaultdict)实现替换默认值
#         na_action - str格式, NaN处理方式. 列表如下:
#             'ignore' - 当arg为function时, nan值不参数处理
#             None - 当arg为function时, nan值照常参与处理
#
# where(cond, other=nan, inplace=False, axis=None, level=None, errors='raise', try_cast=False)
#     在cond为False的地方替换值为other内容. 参数列表如下:
#         cond - Series/array-like/callable格式, 其中元素为bool格式, 代表判定元素是否满足指定条件, 条件为True时, 元素内容不变; 条件为False时, 使用指定值替换
#         other - scalar/Series/callable格式, 当cond参数为False时, 使用该值替换内容
#         inplace - bool格式, 是否进行inplace替换
#         axis - int格式, 沿指定轴进行对齐
#         level - int格式, 沿指定轴的指定索引层级对齐
#         errors - str格式, 可选参数列表:
#             'raise' - 抛出异常exception
#             'ignore' - 忽略异常exception
#
#
#
# pandas.core.groupby.generic模块
# class:
# DataFrameGroupBy
# # DataFrameGroupBy内容格式:
# #     (category_name1, content1),(category_name2, content2),(category_name3, content3),...

# %% [raw]
# 引用:
# [1]official website:
#     https://pandas.pydata.org/
#
# [2]python for data analysis:
#     https://seancheney.gitbook.io/python-for-data-analysis-2nd/
